# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A=np.array([1,2,3,4,5,6])
print(A)
print(type(A))
# Out:
# [1 2 3 4 5 6]
# <class 'numpy.ndarray'>

# %%
arr=np.arange(10,15)
brr=np.log10(arr)
print(brr)
print(np.random.permutation(brr))
# Out:
# [1.         1.04139269 1.07918125 1.11394335 1.14612804]
# [1.14612804 1.07918125 1.         1.04139269 1.11394335]

# %%
a=np.arange(0,100).reshape(10,10)
print(a>50)

plt.plot([1,2,3,4,5],[2,3,4,6,7])
plt.show()
# Out:
# [[False False False False False False False False False False]
#  [False False False False False False False False False False]
#  [False False False False False False False False False False]
#  [False False False False False False False False False False]
#  [False False False False False False False False False False]
#  [False  True  True  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True  True  True]]

# %%
x=np.arange(0,10,0.01)
y=np.sin(x)
y2=np.cos(x)
y3=0.01*x*x
plt.plot(x,y)
plt.plot(x,y2)
plt.plot(x,y3)
plt.show()

# %%
plt.plot(x,x+0,'-g')
plt.plot(x,x+1,'--c')
plt.plot(x,x+2,'-.k')
plt.plot(x,x+3,':r')

# %%
plt.plot(x,np.sin(x))
plt.title("A sin curve")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
#plot1:
x=np.array([0,1,2.3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)

#plot2:
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# f:\Academic\Semester 5\ML\Dr.Rajitha\ML Labs\03_Numpy.ipynb Cell 9 line 5
#       <a href='vscode-notebook-cell:/f%3A/Academic/Semester%205/ML/Dr.Rajitha/ML%20Labs/03_Numpy.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> y=np.array([3,8,1,10])
#       <a href='vscode-notebook-cell:/f%3A/Academic/Semester%205/ML/Dr.Rajitha/ML%20Labs/03_Numpy.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> plt.subplot(1,2,1)
# ----> <a href='vscode-notebook-cell:/f%3A/Academic/Semester%205/ML/Dr.Rajitha/ML%20Labs/03_Numpy.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> plt.plot(x,y)
#       <a href='vscode-notebook-cell:/f%3A/Academic/Semester%205/ML/Dr.Rajitha/ML%20Labs/03_Numpy.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> #plot2:
#       <a href='vscode-notebook-cell:/f%3A/Academic/Semester%205/ML/Dr.Rajitha/ML%20Labs/03_Numpy.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a> x=np.array([0,1,2,3])
#
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv("Book.csv")

# %%
data
# Out:
#   Unnamed: 0  videos  views
# 0   channel1      30  34000
# 1   channel2      40  41000
# 2   channel3      50  42500
# 3   channel4      60  54300
# 4   channel5      70  56000

# %%
plt.scatter(data.videos,data.views)
plt.xlabel("Nunmber of videos")
plt.ylabel("Total views")
plt.show()

# %%
data.views
# Out:
# 0    34000
# 1    41000
# 2    42500
# 3    54300
# 4    56000
# Name: views, dtype: int64

# %%
data.videos
# Out:
# 0    30
# 1    40
# 2    50
# 3    60
# 4    70
# Name: videos, dtype: int64

# %%
x=np.array(data.videos.values)
x
# Out:
# array([30, 40, 50, 60, 70], dtype=int64)

# %%
y=np.array(data.views.values)
y
# Out:
# array([34000, 41000, 42500, 54300, 56000], dtype=int64)

# %%
model=LinearRegression()
model.fit(x.reshape((-1,1)),y)
# Out:
# LinearRegression()

# %%
new_x=np.array([55]).reshape((-1,1))
new_x
# Out:
# array([[55]])

# %%
pred=model.predict(new_x)
pred
# Out:
# array([48425.])

# %%
plt.scatter(data.videos,data.views)
m,c=np.polyfit(x,y,1)
plt.plot(x,m*x+c,color="red")

# %%
m
# Out:
# 572.9999999999997

# %%
c
# Out:
# 16910.000000000022

# %%
y_new=m*55+c
y_new
# Out:
# 48425.0

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv("Book2.csv")
data
# Out:
#   Unnamed: 0  videos  days  subscribers  views
# 0  channel 1      30   150         1800  34000
# 1  channel 2      40   212         1950  41000
# 2  channel 3      50   179         2100  42500
# 3  channel 4      60   346         4300  54300
# 4  channel 5      70   280         4200  56000

# %%
data.days
# Out:
# 0    150
# 1    212
# 2    179
# 3    346
# 4    280
# Name: days, dtype: int64

# %%
data.subscribers
# Out:
# 0    1800
# 1    1950
# 2    2100
# 3    4300
# 4    4200
# Name: subscribers, dtype: int64

# %%
data.videos
# Out:
# 0    30
# 1    40
# 2    50
# 3    60
# 4    70
# Name: videos, dtype: int64

# %%
data.views
# Out:
# 0    34000
# 1    41000
# 2    42500
# 3    54300
# 4    56000
# Name: views, dtype: int64

# %%
model=LinearRegression()
model.fit(data[['videos','days','subscribers']],data.views)
# Out:
# LinearRegression()

# %%
data
# Out:
#   Unnamed: 0  videos  days  subscribers  views
# 0  channel 1      30   150         1800  34000
# 1  channel 2      40   212         1950  41000
# 2  channel 3      50   179         2100  42500
# 3  channel 4      60   346         4300  54300
# 4  channel 5      70   280         4200  56000

# %%
model.predict([[55,200,2500]])
# Out:
# d:\software installs\Anaconda install\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([45930.83976294])

# %%
model.coef_
# Out:
# array([3.81732131e+02, 4.21209097e+01, 3.54006782e-01])

# %%
model.intercept_
# Out:
# 15626.373669488305

# %%
y_new=model.coef_[0]*55+model.coef_[1]*200+model.coef_[2]*2500+model.intercept_

# %%
y_new
# Out:
# 45930.83976294225

# %%
import numpy as np
import matplotlib.pyplot as plt

#number of data points
n=5

#simple dataset
x=np.array([1,2,3,4,5])
y=np.array([5,8,11,14,17])

#start with m=0 and c=0
m=0
c=0

learning_rate=0.01

for i in range (1,11):
    y_predict=m*x+c

    #calculate cost
    cost=(1/n)*sum([value**2 for value in(y-y_predict)])

    #plot after integration cos after m
    plt.scatter(m,cost)

    #calculate gradients
    dm=-(2/n)*sum(x*(y-y_predict))
    dc=-(2/n)*sum(y-y_predict)

    #update parameters
    m=m-learning_rate*dm
    c=c-learning_rate*dc

    print("m{},c{},cost{} iteration{}".format(m,c,cost,i))
    plt.show()
# Out:
# m0.78,c0.22,cost139.0 iteration1
# m1.3752,c0.38880000000000003,cost81.09039999999999 iteration2
# m1.829328,c0.5185120000000001,cost47.342957440000006 iteration3
# m2.1757651200000003,c0.6183820800000001,cost27.676028061184002 iteration4
# m2.4399938688000002,c0.6954685312000001,cost16.214528671342176 iteration5
# m2.641467105792,c0.755159528448,cost9.53475161511504 iteration6
# m2.7950347708108803,c0.8015683115315201,cost5.641529540691357 iteration7
# m2.9120330225405953,c0.8378348590522369,cost3.3721776630341185 iteration8
# m3.00111566603853,c0.8663561805187564,cost2.04914082373806 iteration9
# m3.068888848678928,c0.8889621169460694,cost1.277573393810718 iteration10
